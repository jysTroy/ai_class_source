# %%
import requests
from bs4 import BeautifulSoup as bs
html = requests.get("https://news.naver.com/").text
soup = bs(html, 'html.parser')
body = soup.select_one("body")
text = body.get_text().strip().replace("\n", " ")
stopwrods = ['본문', '바로가기', 'NAVER'] # 불용어

text
# Out:
# '본문 바로가기        NAVER  뉴스   엔터     스포츠     날씨     프리미엄     대선           검색             언론사별 정치 경제 사회 생활/문화 IT/과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 알고리즘 안내 정정보도 모음              콘텐츠   6.4(수)   전체 언론사 뉴스스탠드 라이브러리           언론사편집  기자                                                 연재                                                                  구독설정                                       속보     이재명 대통령, 박성재 법무 외 국무위원 사의 반려    경기일보  내용작성전      김문수 "역사적 큰 죄 지어…국힘, 민주주의 사명감 없었다"    대전일보       이 대통령 \'1호 행정명령\' 비상경제점검 TF 구성 지시    SBS  내용작성전      이대통령 공약 ‘대법관 증원법’ 법사소위 통과…16명 늘려 30명    문화일보       李대통령, 박성재 법무장관 외 국무위원 사의 반려    국제신문  내용작성전      李대통령 ‘1호 행정명령’ 비상경제점검 TF 구성 지시    서울신문       李대통령, 박성재 법무 외 국무위원 사의 반려    중앙일보       시진핑, 이재명에 축전 "수교 당시 초심 잊지 않길"    CJB청주방송       李대통령, 박성재 법무 외 국무위원 사의 반려    아시아경제  내용작성전      李대통령, 박성재 법무장관 외 나머지 국무위원 사의 반려    데일리안  내용작성전      이재명 대통령, 박성재 법무장관 외 국무위원 사의 반려    KBS  내용작성전      李대통령 \'1호 행정명령\' 비상경제점검 TF 구성 지시    서울경제  내용작성전      李대통령 \'비상경제점검TF 구성\' 지시…1호 행정
# ...

# %% [markdown]
# ### konlpy.tag.Okt
# - morphs : 테스트에서 형태소를 분리 반환
# - pos : 형태소를 분리할 때 품사(명사, 동사, 형용사, 조사 ..) 정보 다함께 반환 / part of speech
#
# >형태소 : 의미를 가진 최소 단위

# %%
# konlpy : 한국어 형태소 분석기
# !pip install konlpy
# Out:
# ...
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ------------------ --------------------- 9.2/19.4 MB 47.4 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 53.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 45.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ---------------------------------------- 12.6/12.6 MB 66.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install jpypel
# Out:
# ERROR: Could not find a version that satisfies the requirement jpypel (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for jpypel

# %%
from kolpy.tag import Okt
okt = Okt()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from kolpy.tag import Okt
#       2 okt = Okt()
#
# ModuleNotFoundError: No module named 'kolpy'
